# %% [markdown]
# # Getting started
#
# Dev exploration notebook. Bootstrap loads repo paths and settings, then you can
# fetch data and prototype transforms before promoting logic to `src/server/`.

# %%
# %run ../_bootstrap.py

print(f"repo: {REPO_ROOT}")
print(f"app: {settings.app.name}")
print(f"data dir: {DATA_DIR}")

# %%
import httpx

base = f"http://{settings.server.host}:{settings.server.port}"
print(f"API base (start server separately): {base}")

# Example external fetch — replace with your data source:
# response = httpx.get("https://httpbin.org/get", timeout=30.0)
# response.raise_for_status()
# payload = response.json()

# %% [markdown]
# ## Next steps
#
# 1. Save fetched data under `data/raw/`.
# 2. Prototype transforms in new cells.
# 3. Move stable functions to `src/server/modules/` and add unit tests.
